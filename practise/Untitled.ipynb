# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Titanic_data.csv")

# %%
df[['Age' ,'Fare']].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
female = df[
(df['Fare'] > 100 ) & (df['Sex'] == 'female') ]

# %%
female.shape
# Out:
# (34, 12)

# %%
male = df[
(df['Fare'] > 50) & (df['Sex'] == 'male') ]

# %%
male.shape
# Out:
# (73, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df[df['Cabin'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
#Check wheather the values of columns having not null values
df[df['Cabin'].notna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Accessing Data 
df.loc[1 , 'Name']
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
#Indexing and SLicing data according to age sex and name
df.loc[0:10:2,['Name', 'Age','Sex']]
# Out:
#                                                  Name   Age     Sex
# 0                             Braund, Mr. Owen Harris  22.0    male
# 2                              Heikkinen, Miss. Laina  26.0  female
# 4                            Allen, Mr. William Henry  35.0    male
# 6                             McCarthy, Mr. Timothy J  54.0    male
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 10                    Sandstrom, Miss. Marguerite Rut   4.0  female

# %%
#checks the total number of survived passenger 
survived = df.where(df['Survived'] ==1)

# %%
survived
# Out:
#      PassengerId  Survived  Pclass  \
# 0            NaN       NaN     NaN
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            NaN       NaN     NaN
# ..           ...       ...     ...
# 886          NaN       NaN     NaN
# 887        888.0       1.0     1.0
# 888          NaN       NaN     NaN
# 889        890.0       1.0     1.0
# 890          NaN       NaN     NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 0                                                  NaN     NaN   NaN    NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                                                  NaN     NaN   NaN    NaN
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Give the survived values in term of percentage
df.value_counts('Survived', normalize = True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
#check the number of male survived number
df[df['Sex'] == "male"].value_counts(
    'Survived' 
)
# Out:
# Survived
# 0    468
# 1    109
# Name: count, dtype: int64

# %%
#Check the total number of female survived passenger
df[df['Sex'] == 'female'].value_counts(
    'Survived'
)
# Out:
# Survived
# 1    233
# 0     81
# Name: count, dtype: int64

# %%
#filtering ko sum value niklalna partyo bhane
df.isna().sum()#finding total null values in each columns
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
